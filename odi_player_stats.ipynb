# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("d:/python/datasets/cricket_data.csv")
df
# Out:
#                          Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 0            SR Tendulkar (IND)  1989-2012  463   452  41  18426  200  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234  169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704  164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430  189  32.36
# 4                 V Kohli (IND)  2008-2023  271   262  40  12809  183  57.69
# ..                          ...        ...  ...   ...  ..    ...  ...    ...
# 87          Misbah-ul-Haq (PAK)  2002-2015  162   149  31   5122   96  43.40
# 88               JP Duminy (SA)  2004-2019  199   179  40   5117  150  36.81
# 89         PD Collingwood (ENG)  2001-2011  197   181  37   5092  120  35.36
# 90              A Symonds (AUS)  1998-2009  198   161  33   5088  156  39.75
# 91      Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080  112  29.70
#
#        BF     SR  100  50   0    4s   6s
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Mat        Inns         NO          Runs          HS        Ave  \
# count   92.000000   92.000000  92.000000     92.000000   92.000000  92.000000
# mean   242.423913  228.260870  29.326087   7661.619565  151.347826  39.056957
# std     72.375430   68.164131  15.352352   2488.758889   29.991733   6.192874
# min    128.000000  127.000000   3.000000   5080.000000   96.000000  23.570000
# 25%    194.500000  179.000000  16.000000   5827.250000  131.750000  35.017500
# 50%    231.500000  218.000000  29.500000   6873.500000  145.000000  38.690000
# 75%    274.750000  258.250000  40.000000   8661.250000  173.250000  42.190000
# max    463.000000  452.000000  84.000000  18426.000000  264.000000  57.690000
#
#                  BF          SR        100         50          0           4s  \
# count     92.000000   92.000000  92.000000  92.000000  92.000000    92.000000
# mean    9610.663043   80.386630  12.304348  46.304348  13.000000   692.358696
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  92 non-null     object
#  1   Span    92 non-null     object
#  2   Mat     92 non-null     int64
#  3   Inns    92 non-null     int64
#  4   NO      92 non-null     int64
#  5   Runs    92 non-null     int64
#  6   HS      92 non-null     int64
#  7   Ave     92 non-null     float64
#  8   BF      92 non-null     int64
#  9   SR      92 non-null     float64
#  10  100     92 non-null     int64
#  11  50      92 non-null     int64
#  12  0       92 non-null     int64
#  13  4s      92 non-null     int64
#  14  6s      92 non-null     int64
# dtypes: float64(2), int64(11), object(2)
# memory usage: 10.9+ KB

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
df.corr()
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_13668\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            Mat      Inns        NO      Runs        HS       Ave        BF  \
# Mat   1.000000  0.989675  0.482304  0.838710  0.117893 -0.213406  0.798829
# Inns  0.989675  1.000000  0.381501  0.874313  0.171142 -0.218087  0.840038
# NO    0.482304  0.381501  1.000000  0.282171 -0.277406  0.192390  0.306632
# Runs  0.838710  0.874313  0.282171  1.000000  0.410889  0.215598  0.933103
# HS    0.117893  0.171142 -0.277406  0.410889  1.000000  0.297695  0.241711
# Ave  -0.213406 -0.218087  0.192390  0.215598  0.297695  1.000000  0.132616
# BF    0.798829  0.840038  0.306632  0.933103  0.241711  0.132616  1.000000
# SR    0.094349  0.072575 -0.076982  0.138514  0.437712  0.199802 -0.214101
# ...

# %%
df['100'].sum()
# total no. of 100s combined
# we can also add other values
# Out:
# 1132

# %%
df['6s'].sum()
# Out:
# 9007

# %%
df['4s'].sum()
# Out:
# 63697

# %%
six = df['6s'].sum()
four = df['4s'].sum()
data=[six,four]
boundary=['6s','4s']

# %%
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d})".format(pct, absolute)

# to make a seperate pie
explode = (0.1,0)

plt.pie(data,autopct = lambda pct: func(pct, data),labels=boundary,explode=explode)
plt.legend(boundary,title ="no. of boundary %",loc ="lower left",bbox_to_anchor =( 0.5, 1))
# plt.title("no. of boundary percentage")
plt.show()

# %%
df['Runs'].sum()
# Out:
# 704869

# %%
names =df['Player']
names
# Out:
# 0              SR Tendulkar (IND)
# 1     KC Sangakkara (Asia/ICC/SL)
# 2            RT Ponting (AUS/ICC)
# 3         ST Jayasuriya (Asia/SL)
# 4                   V Kohli (IND)
#                  ...
# 87            Misbah-ul-Haq (PAK)
# 88                 JP Duminy (SA)
# 89           PD Collingwood (ENG)
# 90                A Symonds (AUS)
# 91        Abdul Razzaq (Asia/PAK)
# Name: Player, Length: 92, dtype: object

# %%
names = df['Player']
names
players_list=[]
for name in names:
    players_list.append(name)
    
players_list
# Out:
# ['SR Tendulkar (IND)',
#  'KC Sangakkara (Asia/ICC/SL)',
#  'RT Ponting (AUS/ICC)',
#  'ST Jayasuriya (Asia/SL)',
#  'V Kohli (IND)',
#  'DPMD Jayawardene (Asia/SL)',
#  'Inzamam-ul-Haq (Asia/PAK)',
#  'JH Kallis (Afr/ICC/SA)',
#  'SC Ganguly (Asia/IND)',
#  'R Dravid (Asia/ICC/IND)',
#  'MS Dhoni (Asia/IND)',
#  'CH Gayle (ICC/WI)',
#  'BC Lara (ICC/WI)',
#  'TM Dilshan (SL)',
#  'RG Sharma (IND)',
#  'Mohammad Yousuf (Asia/PAK)',
#  'AC Gilchrist (AUS/ICC)',
#  'AB de Villiers (Afr/SA)',
#  'M Azharuddin (IND)',
#  'PA de Silva (SL)',
#  'Saeed Anwar (PAK)',
#  'S Chanderpaul (WI)',
#  'Yuvraj Singh (Asia/IND)',
#  'DL Haynes (WI)',
#  'LRPL Taylor (NZ)',
#  'MS Atapattu (SL)',
#  'ME Waugh (AUS)',
#  'V Sehwag (Asia/ICC/IND)',
#  'HM Amla (SA)',
#  'HH Gibbs (SA)',
#  'Tamim Iqbal (BAN)',
#  'Shahid Afridi (Asia/ICC/PAK)',
#  'SP Fleming (ICC/NZ)',
#  'MJ Clarke (AUS)',
#  'EJG Morgan (ENG/IRE)',
#  'SR Waugh (AUS)',
#  'Shoaib Malik (PAK)',
#  'A Ranatunga (SL)',
# ...

# %% [markdown]
# individual player statistics

# %%
df[df['Player']=='SR Tendulkar (IND)'].sum() # .values_counts() can also be used
# Out:
# Player    SR Tendulkar (IND)
# Span               1989-2012
# Mat                      463
# Inns                     452
# NO                        41
# Runs                   18426
# HS                       200
# Ave                    44.83
# BF                     21368
# SR                     86.23
# 100                       49
# 50                        96
# 0                         20
# 4s                      2016
# 6s                       195
# dtype: object

# %%
df[df['Player']=='RG Sharma (IND)'].sum() # .values_counts() can also be used
# Out:
# Player    RG Sharma (IND)
# Span            2007-2023
# Mat                   241
# Inns                  234
# NO                     34
# Runs                 9782
# HS                    264
# Ave                 48.91
# BF                  10882
# SR                  89.89
# 100                    30
# 50                     48
# 0                      14
# 4s                    896
# 6s                    273
# dtype: object

# %% [markdown]
# top 10 most scoring bater

# %%
df_first10 = df.head(10)
plt.figure(figsize=(20,6))
plt.bar(df_first10['Player'],df_first10['Runs'])
plt.title('total Runs scorrer', fontsize=14)
plt.xticks(rotation=45)
plt.xlabel('names of cricketer')
plt.ylabel('Runs')

for i, v in enumerate(df_first10['Runs']):
    plt.text(i, v + 2, str(v), color='black', fontweight='bold',fontsize=15)

# %%
df.sort_values(by=['Ave', 'Player'], ascending=[False, True], inplace=True)
df_top10_average = df.head(12)
df_top10_average

plt.figure(figsize=(15,6))
plt.bar(df_top10_average['Player'],df_top10_average['Ave'])
plt.xticks(rotation=45)
plt.xlabel('names of cricketer')
plt.ylabel('Average')
plt.title("top 10 best batting average")

for i, v in enumerate(df_top10_average['Ave']):
    plt.text(i, v + 2, str(v), color='black', fontweight='bold',fontsize=13)

# %%
df.sort_values(by=['HS','Player'], ascending=[False, True], inplace=True)
df_hs = df.head(10)
df_hs

plt.figure(figsize=(15,6))
plt.bar(df_hs['Player'],df_hs['HS'])
plt.xticks(rotation=45)
plt.xlabel('names of cricketer')
plt.ylabel('Highest score')
plt.title("top 10 highest batting score(has more than 5000 runs in ODI)")

for i, v in enumerate(df_hs['HS']):
    plt.text(i, v + 2, str(v), color='black', fontweight='bold',fontsize=13)
